# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

import pandas as pd
import codecs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3ae3419af99a> in <module>
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5
# ----> 6 import pandas as pd
#       7 import codecs
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # Parabola

# %%
xmin, xmax= -1, 3
a, b, c = -1, 1, -1

x = np.linspace(xmin, xmax)
y = a* x**2 + b*x + c
ymin, ymax = np.min(y), np.max([1,np.max(y)])

xticks = np.arange(int(xmin), int(xmax)+1)
yticks = np.arange(int(ymin), int(ymax)+1)

fig = plt.figure(figsize=(8,4))
ax = fig.gca()

for xt in xticks:
    ax.axvline(x=xt, ymin=ymin, ymax=ymax, lw=1, ls='-.' if xt != 0 else '-', color='k'  if xt == 0 else 'lightgrey')

for yt in yticks:
    ax.axhline(y=yt, lw=1, ls='-.' if yt != 0 else '-', color='k' if yt == 0 else 'lightgrey')

    


ax.plot(x, y, c='g', lw=2, label=f"$y={a}x^2+{b}x+{c}$")

# plt.scatter(dots, dots**2, c='r', s=7)


ax.legend()
plt.savefig('./pics/parabola4.png')
plt.show()

# %% [markdown]
# $y=x^2$
#
# $y = -x$
#
# $y = x^2 - x$

# %%
t = pd.DataFrame({'x': np.linspace(0,1,11), '$f(x)=x^2$': np.linspace(0,1,11)**2})
t = t.set_index('x')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e6bd7e685b4f> in <module>
# ----> 1 t = pd.DataFrame({'x': np.linspace(0,1,11), '$f(x)=x^2$': np.linspace(0,1,11)**2})
#       2 t = t.set_index('x')
#
# NameError: name 'pd' is not defined

# %%
t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-34fc7a11cb38> in <module>
# ----> 1 t
#
# NameError: name 't' is not defined

# %%
st = t.to_latex().replace('\n', ' ').replace('\\\\', r"\ ")
st
# Out:
# '\\begin{tabular}{lr} \\toprule {} &  \\$f(x)=x\\textasciicircum 2\\$ \\  x   &             \\  \\midrule 0.0 &        0.00 \\  0.1 &        0.01 \\  0.2 &        0.04 \\  0.3 &        0.09 \\  0.4 &        0.16 \\  0.5 &        0.25 \\  0.6 &        0.36 \\  0.7 &        0.49 \\  0.8 &        0.64 \\  0.9 &        0.81 \\  1.0 &        1.00 \\  \\bottomrule \\end{tabular} '

# %% [markdown]
# \\begin{tabular}{lrr}\n\\toprule\n{} &    x &  \\$f(x)=x\\textasciicircum 2\\$ \\\\\n\\midrule\n0  &  0.0 &        0.00 \\\\\n1  &  0.1 &        0.01 \\\\\n2  &  0.2 &        0.04 \\\\\n3  &  0.3 &        0.09 \\\\\n4  &  0.4 &        0.16 \\\\\n5  &  0.5 &        0.25 \\\\\n6  &  0.6 &        0.36 \\\\\n7  &  0.7 &        0.49 \\\\\n8  &  0.8 &        0.64 \\\\\n9  &  0.9 &        0.81 \\\\\n10 &  1.0 &        1.00 \\\\\n\\bottomrule\n\\end{tabular}\n

# %%
codecs.decode(st, 'unicode')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-7-605f258093ca> in <module>
# ----> 1 codecs.decode(st, 'unicode')
#
# LookupError: unknown encoding: unicode
