# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, Wedge, Polygon
from matplotlib.collections import PatchCollection

plt.rc('text', usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
# matplotlib.verbose.level = 'debug-annoying'

# %matplotlib inline

# %%
def set_axes(ax):
    xmin, xmax= ax.get_xlim()
    ymin, ymax= ax.get_ylim()
    
    xticks = np.arange(int(xmin), int(xmax)+1)
    yticks = np.arange(int(ymin), int(ymax)+1)

    for xt in xticks:
        ax.axvline(x=xt, ymin=ymin, ymax=ymax, lw=1, ls='-.' if xt != 0 else '-', color='k'  if xt == 0 else 'lightgrey')

    for yt in yticks:
        ax.axhline(y=yt, lw=1, ls='-.' if yt != 0 else '-', color='k' if yt == 0 else 'lightgrey')

    ax.tick_params(axis='both', which='major', labelsize=16)
    ax.set_xticks(ticks=xticks)
    ax.set_yticks(ticks=yticks)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
ax.set_xlim(-2, 8)
ax.set_ylim(-2, 8)

patches = []

polygon = Polygon([[1,1],[12,12],[-13,15]], True)
patches.append(polygon)

    
colors = 100 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.4)
p.set_array(colors)
ax.add_collection(p)
# fig.colorbar(p, ax=ax)

text = r'\begin{equation*}'
text += r'\begin{cases} '
text += r'y > x \\'
text += r'y > 2 - x \\' 
text += r'\end{cases}'
text += r'\end{equation*}'
plt.text(1, 4, text, fontsize=34)

set_axes(ax)
plt.savefig('pics/uklad_nierowm1.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-2f164c75a49a> in <module>
#      25
#      26 set_axes(ax)
# ---> 27 plt.savefig('pics/uklad_nierowm1.png')
#      28 plt.show()
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# /usr/lib/python3/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ...

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
ax.set_xlim(-4, 6)
ax.set_ylim(0, 8)

patches = []

polygon = Polygon([[1,1],[-3,5], [5,5]], True)
patches.append(polygon)

    
colors = 100 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.4)
p.set_array(colors)
ax.add_collection(p)
# fig.colorbar(p, ax=ax)

text = r'\begin{equation*}'
text += r'\begin{cases} '
text += r'y > x \\'
text += r'y > 2 - x \\' 
text += r'y < 5 \\' 
text += r'\end{cases}'
text += r'\end{equation*}'
plt.text(0, 3, text, fontsize=34)

set_axes(ax)
plt.savefig('../pics/uklad_nierowm2.png')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
ax.set_xlim(-2, 8)
ax.set_ylim(-2, 8)

patches = []

polygon = Polygon([[6,1],[-12,4],[-12,10]], True)
patches.append(polygon)

    
colors = 100 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.4)
p.set_array(colors)
ax.add_collection(p)
# fig.colorbar(p, ax=ax)

# text = r'\begin{equation*}'
# text += r'\begin{cases} '
# text += r'y > x \\'
# text += r'y > 2 - x \\' 
# text += r'\end{cases}'
# text += r'\end{equation*}'
# plt.text(1, 4, text, fontsize=34)

set_axes(ax)
plt.savefig('../pics/uklad_nierowm3.png')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
ax.set_xlim(-2, 8)
ax.set_ylim(-2, 8)

patches = []

polygon = Polygon([[-1,-1],[99,19],[-2-10,4+50]], True)
patches.append(polygon)

    
colors = 100 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.4)
p.set_array(colors)
ax.add_collection(p)
# fig.colorbar(p, ax=ax)

# text = r'\begin{equation*}'
# text += r'\begin{cases} '
# text += r'y > x \\'
# text += r'y > 2 - x \\' 
# text += r'\end{cases}'
# text += r'\end{equation*}'
# plt.text(1, 4, text, fontsize=34)

set_axes(ax)
plt.savefig('../pics/uklad_nierowm4.png')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
ax.set_xlim(-2, 8)
ax.set_ylim(-2, 8)

patches = []

polygon = Polygon([[1, 1],[6,1], [6,7], [1,7]], True)
patches.append(polygon)

    
colors = 100 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.4)
p.set_array(colors)
ax.add_collection(p)
# fig.colorbar(p, ax=ax)

text = r'\begin{equation*}'
text += r'\begin{cases} '
text += r'y > x \\'
text += r'y > 2 - x \\' 
text += r'y < 5 \\' 
text += r'\end{cases}'
text += r'\end{equation*}'
# plt.text(0, 3, text, fontsize=34)

set_axes(ax)
plt.savefig('pics/uklad_nierowm5.png')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
ax.set_xlim(-2, 8)
ax.set_ylim(-2, 8)

patches = []

polygon = Polygon([[1,-1], [7,1], [5,7]], True)
patches.append(polygon)

    
colors = 100 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.6)
# p.set_array(colors)
ax.add_collection(p)

set_axes(ax)
plt.savefig('../pics/uklad_nierowm6.png')
plt.show()

# %%
w = 10
l = -2
fig = plt.figure(figsize=(w, w))
ax = fig.gca()
ax.set_xlim(l, l + w)
ax.set_ylim(l, l + w)

patches = []

polygon = Polygon([[-1,0], [4,-1], [25,20], [24,25]], True)
patches.append(polygon)

colors = 255 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.6)
# p.set_array(colors)
ax.add_collection(p)

set_axes(ax)
plt.savefig('../pics/uklad_nierowm8.png')
plt.show()

# %%
w = 10
l = -2
fig = plt.figure(figsize=(w, w))
ax = fig.gca()
ax.set_xlim(l, l + w)
ax.set_ylim(l, l + w)

patches = []

polygon = Polygon([[-1,3], [1,-1], [5,1], [5,6]], True)
patches.append(polygon)

colors = 255 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.6)
# p.set_array(colors)
ax.add_collection(p)

set_axes(ax)
plt.savefig('../pics/uklad_nierowm8.png')
plt.show()

# %%
w = 10
l = -5
fig = plt.figure(figsize=(w, w))
ax = fig.gca()
ax.set_xlim(l, l + w)
ax.set_ylim(l, l + w)

patches = []

x  = np.linspace(l, l+w)


ax.fill_between(x, x**2, x**2 - 4)

# polygon = Polygon([[-1,3], [1,-1], [5,1], [5,6]], True)
# patches.append(polygon)

# colors = 255 * np.random.rand(len(patches))
# p = PatchCollection(patches, alpha=0.6)
# # p.set_array(colors)
# ax.add_collection(p)

set_axes(ax)
plt.savefig('../pics/area_0.png')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
ax.set_xlim(-2, 8)
ax.set_ylim(-2, 8)

patches = []

polygon = Polygon([[-1,-1],[14,2],[14,8]], True)
patches.append(polygon)

    
colors = 100 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.6)
p.set_array(colors)
ax.add_collection(p)
# fig.colorbar(p, ax=ax)

# text = r'\begin{equation*}'
# text += r'\begin{cases} '
# text += r'y > x \\'
# text += r'y > 2 - x \\' 
# text += r'\end{cases}'
# text += r'\end{equation*}'
# plt.text(1, 4, text, fontsize=34)

set_axes(ax)
plt.savefig('../pics/obszar1.png')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
ax.set_xlim(-2, 8)
ax.set_ylim(-2, 8)

patches = []

polygon = Polygon([[-1,1],[9,3],[9,-4]], True)
patches.append(polygon)

    
colors = 100 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.6)
p.set_array(colors)
ax.add_collection(p)
# fig.colorbar(p, ax=ax)

# text = r'\begin{equation*}'
# text += r'\begin{cases} '
# text += r'y > x \\'
# text += r'y > 2 - x \\' 
# text += r'\end{cases}'
# text += r'\end{equation*}'
# plt.text(1, 4, text, fontsize=34)

set_axes(ax)
plt.savefig('../pics/obszar2.png')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
ax.set_xlim(-2, 8)
ax.set_ylim(-2, 8)

patches = []

polygon = Polygon([[2,-1],[-2,9],[7,9]], True)
patches.append(polygon)

    
colors = 100 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.6)
p.set_array(colors)
ax.add_collection(p)

set_axes(ax)
plt.savefig('../pics/obszar3.png')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
ax.set_xlim(-2, 8)
ax.set_ylim(-2, 8)

patches = []

polygon = Polygon([[3,7],[-2,-3],[7,-3]], True)
patches.append(polygon)

    
colors = 100 * np.random.rand(len(patches))
p = PatchCollection(patches, alpha=0.6)
p.set_array(colors)
ax.add_collection(p)

set_axes(ax)
plt.savefig('../pics/obszar4.png')
plt.show()
